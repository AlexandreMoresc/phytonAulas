# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()

driver.get('https://google.com')
driver.fullscreen_window()
campo = driver.find_element(By.ID, 'APjFqb')
campo.send_keys('04.266.331/0019-58' + Keys.ENTER)
# Out:
# cnpj=<selenium.webdriver.remote.webelement.WebElement (session="01547cb58a07f8dab894c8b19880f391", element="f.D88867B1AE399FAE40AF3224BCAA8ED1.d.19EE6E879A87C2CFD69B9CB0EEA45772.e.2")>
